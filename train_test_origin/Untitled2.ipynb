# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('resnet50_moth_classifier_hie.log', sep='\t')

# %%
df
# Out:
#      epoch   time_cost  train_loss  valid_loss    t_center   t_species  \
# 0        1      518.02   13.244909    9.296710    0.849518    6.184450
# 1        2     1035.56    7.573775    5.910656    0.679940    3.949343
# 2        3     1553.19    5.175228    4.385036    0.719416    2.812033
# 3        4     2068.89    3.911377    3.432225    0.698291    2.160916
# 4        5     2587.17    3.163751    2.878860    0.665870    1.754631
# ..     ...         ...         ...         ...         ...         ...
# 134    135    69944.07    0.754908    1.210011    0.332221    0.357787
# 135    136    70460.81    0.719944    0.980592    0.327364    0.339632
# 136    137    70976.29    0.767676    1.449387    0.330995    0.360523
# 137    138    71492.67    0.722737    1.023243    0.329444    0.339186
# 138    139    72008.69    0.684969    1.032372    0.322075    0.321097
#
#         t_genus    t_family    v_center   v_species     v_genus    v_family  \
# ...

# %%
df.iloc[np.argmin(df.valid_loss.values)]
# Out:
# epoch            136.000000
#  time_cost     70460.810000
# train_loss         0.719944
# valid_loss         0.980592
#   t_center         0.327364
#  t_species         0.339632
#    t_genus         0.046907
#   t_family         0.006041
#   v_center         0.349609
#  v_species         0.474317
#    v_genus         0.137986
#   v_family         0.018680
# Unnamed: 12             NaN
# Name: 135, dtype: float64

# %%
df.iloc[np.argmin(df.valid_loss.values)]
# Out:
# epoch            136.000000
#  time_cost     70460.810000
# train_loss         0.719944
# valid_loss         0.980592
#   t_center         0.327364
#  t_species         0.339632
#    t_genus         0.046907
#   t_family         0.006041
#   v_center         0.349609
#  v_species         0.474317
#    v_genus         0.137986
#   v_family         0.018680
# Unnamed: 12             NaN
# Name: 135, dtype: float64
