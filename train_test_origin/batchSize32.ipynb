# %%
import pandas as pd

# %%
logfile = pd.read_csv('resnet50_moth_classifier_log_batchSize32.log', sep = '\t')

# %%
logfile
# Out:
#     epoch      time  train_loss  valid_loss  Unnamed: 4
# 0       1    661.12    4.498759    2.588614         NaN
# 1       2   1174.43    1.999680    1.477791         NaN
# 2       3   1689.19    1.177651    1.080878         NaN
# 3       4   2202.04    0.823562    0.900012         NaN
# 4       5   2717.64    0.652903    0.751696         NaN
# 5       6   3235.13    0.553134    0.771083         NaN
# 6       7   3748.99    0.488000    0.669285         NaN
# 7       8   4263.25    0.450354    0.659181         NaN
# 8       9   4775.89    0.421477    0.656978         NaN
# 9      10   5291.26    0.393815    0.654843         NaN
# 10     11   5804.88    0.374784    0.653727         NaN
# 11     12   6320.70    0.358844    0.609625         NaN
# 12     13   6836.85    0.353984    0.620645         NaN
# 13     14   7353.03    0.344298    0.620864         NaN
# 14     15   7864.93    0.329260    0.600406         NaN
# 15     16   8381.95    0.319149    0.606552         NaN
# ...

# %%
logfile.plot(x = 'epoch', y = ['train_loss', 'valid_loss'])

# %%
logfile = pd.read_csv('valid_and_test_moth_classification.csv', sep = '\t')

# %%
logfile
# Out:
#                        file  true_id  pred_id  \
# 0      A37-20151210-028.jpg     1067     1067
# 1      V18-20150610-070.jpg     1439     1439
# 2      V33-20171222-102.jpg     1320     1320
# 3      V33-20170714-079.jpg     1997      331
# 4      A48-20160601-145.jpg      420      420
# ...                     ...      ...      ...
# 19347  A34-20151006-099.jpg     2175     2175
# 19348  V31-20170909-054.jpg     1059     1431
# 19349  A58-20170303-006.jpg     2094     2094
# 19350  A41-20180621-110.jpg     1417     1420
# 19351  V22-20161113-018.jpg      499      499
#
#                                true_name                          pred_name  \
# 0                      Hepatica irrorata                  Hepatica irrorata
# 1                         Medama diplaga                     Medama diplaga
# 2      Lomographa platyleucata marginata  Lomographa platyleucata marginata
# 3             Psilalcis breta rantaizana            Blasticorhinus rivulosa
# ...

# %%
logfile.plot(x = 'true_id', y ='probs')
